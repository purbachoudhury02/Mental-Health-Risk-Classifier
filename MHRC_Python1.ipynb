# %%
name=input("Enter your name: ")
age=int(input("Enter your age: "))
subjects = []
n = int(input("How many subjects do you have? "))
for i in range(n):
    subject = input("Enter subject: ")
    subjects.append(subject)
print("These are your subjects: ")
for i in subjects:
    print(i)
sleepHours=int(input("Enter your total hours of sleep: "))
if (sleepHours<=6):
               print("At risk")
else:
    print("Not at risk")
# Out:
# Enter your name:  joe
# Enter your age:  20
# How many subjects do you have?  5
# Enter subject:  physics
# Enter subject:  chemistry
# Enter subject:  mathematics
# Enter subject:  english
# Enter subject:  IT
# These are your subjects:
# physics
# chemistry
# mathematics
# english
# IT
# Enter your total hours of sleep:  5
# At risk
